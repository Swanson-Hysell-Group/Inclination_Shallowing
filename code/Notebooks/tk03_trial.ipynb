# %% [markdown]
# # Notebook for trying out the TK03 model and the Elongation/Inclination Method of correcting for inclination shallowing

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import pmagpy.ipmag as ipmag
import pmagpy.pmag as pmag

import matplotlib.pyplot as plt
from IPython.display import display
import matplotlib as mpl
from matplotlib import cm

# %config InlineBackend.figure_format = 'retina'

# %%
Cutface_specimens = pd.read_csv('../data/Pmag/cutface/specimens.txt', sep='\t', header=1)

Cutface_lat = 47.73055
Cutface_lon = -90.44128

# %%
specimens_lt_geo = Cutface_specimens[(Cutface_specimens['dir_comp']=='lt') & (Cutface_specimens['dir_tilt_correction']==0)]
specimens_lt_tc = Cutface_specimens[(Cutface_specimens['dir_comp']=='lt') & (Cutface_specimens['dir_tilt_correction']==100)]

specimens_mt_geo = Cutface_specimens[(Cutface_specimens['dir_comp']=='mt') & (Cutface_specimens['dir_tilt_correction']==0)]
specimens_mt_tc = Cutface_specimens[(Cutface_specimens['dir_comp']=='mt') & (Cutface_specimens['dir_tilt_correction']==100)]

specimens_ht_geo = Cutface_specimens[(Cutface_specimens['dir_comp']=='ht') & (Cutface_specimens['dir_tilt_correction']==0)]
specimens_ht_tc = Cutface_specimens[(Cutface_specimens['dir_comp']=='ht') & (Cutface_specimens['dir_tilt_correction']==100)]

# %%
mean_lt = ipmag.fisher_mean(specimens_lt_geo['dir_dec'].tolist(),specimens_lt_geo['dir_inc'].tolist())
mean_mt = ipmag.fisher_mean(specimens_mt_tc['dir_dec'].tolist(),specimens_mt_tc['dir_inc'].tolist())
mean_ht = ipmag.fisher_mean(specimens_ht_tc['dir_dec'].tolist(),specimens_ht_tc['dir_inc'].tolist())
mean_ht
# Out:
# {'dec': 285.10893622254355,
#  'inc': 29.67624976213083,
#  'n': 81,
#  'r': 78.44177849626185,
#  'k': 31.271725252524657,
#  'alpha95': 2.85866289800105,
#  'csd': 14.48468643344844}

# %% [markdown]
# ## Get directions from tk03 model

# %%
tk03_directions=ipmag.tk03(n=100,dec=0, lat=30)

# %%
def get_decs(directions):
    return [item[0] for item in directions]
def get_incs(directions):
    return [item[1] for item in directions]

# %%
tk03_decs=get_decs(tk03_directions)
tk03_incs=get_incs(tk03_directions)
tk03_mean_data=ipmag.fisher_mean(tk03_decs,tk03_incs)

# %% [markdown]
# ### Plot original directions

# %%
fignum = 1
plt.figure(num=fignum,figsize=(6,6))
ipmag.plot_net(fignum)

ipmag.plot_di(tk03_decs,tk03_incs,markersize=50)
plt.savefig('../figures/tk03_original.pdf')
plt.legend(loc=8)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
tk03_mean_data
# Out:
# {'dec': 359.2982458784473,
#  'inc': 46.23827609151338,
#  'n': 100,
#  'r': 91.11060670478479,
#  'k': 11.136868030497372,
#  'alpha95': 4.437367312926926,
#  'csd': 24.27188368202617}

# %% [markdown]
# ### Squish the inclinations with various factors of $f$ and plot

# %%
tk03_incs_squished=ipmag.squish(tk03_incs, 0.4)
fignum = 1
plt.figure(num=fignum,figsize=(6,6))
ipmag.plot_net(fignum)

ipmag.plot_di(tk03_decs,tk03_incs_squished,markersize=50)
plt.legend(loc=8)
plt.savefig('../figures/tk03_squished.pdf')
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
ipmag.fisher_mean(tk03_decs,tk03_incs_squished)
# Out:
# {'dec': 359.44805660582006,
#  'inc': 24.02759769446875,
#  'n': 100,
#  'r': 92.43910444465442,
#  'k': 13.093687020978173,
#  'alpha95': 4.062702178831049,
#  'csd': 22.38484239562552}

# %% [markdown]
# ## Try out $ e/i $ method and compare to original plot

# %%
tk03_data_nested=ipmag.make_di_block(tk03_decs,tk03_incs_squished)

ipmag.find_ei(np.array(tk03_data_nested),save=True,save_folder='./tk3_output')
# Out:
# Bootstrapping.... be patient
#
# The original inclination was: 25.003183411941823
#
# The corrected inclination is: 50.54102436002918
# with bootstrapped confidence bounds of: 36.625795215262144 to 62.67516711729919
# and elongation parameter of: 1.6703649654744925
# The flattening factor is: 0.36999999999999944

# %% [markdown]
# ## Apply to Cutface data

# %%
specimens_ht_tc.head()
# Out:
#    specimen      experiments sample  dir_alpha95 dir_comp  dir_dec  dir_inc  \
# 7    CF-10a  CF-10a_LP-DIR-T  CF-10          NaN       ht    283.4     25.4
# 19   CF-11a  CF-11a_LP-DIR-T  CF-11          NaN       ht    285.1     34.9
# 21   CF-12a  CF-12a_LP-DIR-T  CF-12          NaN       ht    269.8     32.1
# 32   CF-13a  CF-13a_LP-DIR-T  CF-13          NaN       ht    264.1     24.7
# 47   CF-14a  CF-14a_LP-DIR-T  CF-14          NaN       ht    280.0     14.3
#
#     dir_n_comps  dir_n_measurements  dir_tilt_correction  dir_dang  \
# 7           3.0                 7.0                100.0       0.0
# 19          3.0                 7.0                100.0       0.0
# 21          3.0                 4.0                100.0       0.0
# 32          3.0                 7.0                100.0       0.0
# 47          3.0                 7.0                100.0       0.0
#
#     dir_mad_free  meas_step_max  meas_step_min meas_step_unit analysts  \
# 7           10.1          950.0          937.0              K      NaN
# 19          13.2          950.0          937.0              K      NaN
# 21          20.8          947.0          937.0              K      NaN
# 32          12.1          950.0          937.0              K      NaN
# 47           5.7          950.0          937.0              K      NaN
#
#                 instrument_codes         software_packages int_corr  \
# 7   hargrave 2020-11-24 21:43:43  pmagpy-4.2.50: demag_gui        u
# 19  hargrave 2020-11-22 16:19:20  pmagpy-4.2.50: demag_gui        u
# 21  hargrave 2020-11-22 16:20:48  pmagpy-4.2.50: demag_gui        u
# 32  hargrave 2020-11-24 21:45:14  pmagpy-4.2.50: demag_gui        u
# 47  hargrave 2020-11-24 21:46:50  pmagpy-4.2.50: demag_gui        u
#
#      citations                   method_codes result_quality  volume  weight  \
# 7   This study  LP-DIR-T:DE-BFL-A:DA-DIR-TILT              g     NaN     NaN
# 19  This study  LP-DIR-T:DE-BFL-A:DA-DIR-TILT              g     NaN     NaN
# 21  This study  LP-DIR-T:DE-BFL-A:DA-DIR-TILT              g     NaN     NaN
# 32  This study  LP-DIR-T:DE-BFL-A:DA-DIR-TILT              g     NaN     NaN
# 47  This study  LP-DIR-T:DE-BFL-A:DA-DIR-TILT              g     NaN     NaN
#
#          location site specimen_name
# 7   Cutface Creek   CF        CF-10a
# 19  Cutface Creek   CF        CF-11a
# 21  Cutface Creek   CF        CF-12a
# 32  Cutface Creek   CF        CF-13a
# 47  Cutface Creek   CF        CF-14a

# %%
ht_tc_di_block = ipmag.make_di_block(specimens_ht_tc['dir_dec'].tolist(),specimens_ht_tc['dir_inc'].tolist())

# %%
ipmag.find_ei(ht_tc_di_block)
# Out:
# Bootstrapping.... be patient
#
# The original inclination was: 29.72467720058886
#
# The corrected inclination is: 42.056575591348256
# with bootstrapped confidence bounds of: 31.871706721574576 to 53.01425210811141
# and elongation parameter of: 1.8989971373494174
# The flattening factor is: 0.6149999999999997

# %%
specimens_ht_tc = specimens_ht_tc.head(1)

# %%
ipmag.find_ei(np.array(ht_tc_di_block))
# Out:
# Bootstrapping.... be patient
#
# The original inclination was: 29.72467720058886
#
# The corrected inclination is: 42.056575591348256
# with bootstrapped confidence bounds of: 31.328889144942647 to 51.9850246065044
# and elongation parameter of: 1.8989971373494174
# The flattening factor is: 0.6149999999999997
